# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Testing regression

# %%
dataset = pd.read_csv('data/regression/car_dataset.csv')
X = dataset.drop(['Car_Name','Selling_Price'],axis=1)
Y = dataset['Selling_Price']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state=2)

# %%
from ubml.train_test import regression_train_test

metrics_performance, best_model = regression_train_test(x_train=X_train, y_train=Y_train, x_test=X_test, y_test=Y_test)

# %%
metrics_performance
# Out:
#                            r2 score train  r2 score test  \
# Linear Regression                   0.880          0.837
# Lasso Regression                    0.843          0.871
# Ridge Regression                    0.880          0.840
# Support Vector Regression          -0.078          0.109
# Decision Tree Regression            1.000          0.943
# Random Forest Regression            0.985          0.983
#
#                            mean squared error train  mean squared error test  \
# Linear Regression                             3.259                    2.150
# Lasso Regression                              4.268                    1.698
# Ridge Regression                              3.260                    2.104
# Support Vector Regression                    29.252                   11.729
# Decision Tree Regression                      0.000                    0.750
# Random Forest Regression                      0.405                    0.222
#
#                            root mean squared error train  \
# Linear Regression                                  1.805
# Lasso Regression                                   2.066
# Ridge Regression                                   1.806
# Support Vector Regression                          5.409
# Decision Tree Regression                           0.000
# Random Forest Regression                           0.636
#
#                            root mean squared error test  \
# Linear Regression                                 1.466
# Lasso Regression                                  1.303
# Ridge Regression                                  1.450
# Support Vector Regression                         3.425
# Decision Tree Regression                          0.866
# Random Forest Regression                          0.471
#
#                            mean absolute error train  \
# Linear Regression                              1.217
# Lasso Regression                               1.286
# Ridge Regression                               1.213
# Support Vector Regression                      3.236
# Decision Tree Regression                       0.000
# Random Forest Regression                       0.249
#
#                            mean absolute error test  \
# Linear Regression                             1.152
# Lasso Regression                              1.051
# Ridge Regression                              1.143
# Support Vector Regression                     2.679
# Decision Tree Regression                      0.495
# Random Forest Regression                      0.321
#
#                            explained variance score train  \
# Linear Regression                                   0.880
# Lasso Regression                                    0.843
# Ridge Regression                                    0.880
# Support Vector Regression                          -0.003
# Decision Tree Regression                            1.000
# Random Forest Regression                            0.985
#
#                            explained variance score test  max error train  \
# Linear Regression                                  0.846           11.078
# Lasso Regression                                   0.871           12.380
# Ridge Regression                                   0.849           11.113
# Support Vector Regression                          0.161           31.218
# Decision Tree Regression                           0.943            0.000
# Random Forest Regression                           0.984            6.946
#
#                            max error test
# Linear Regression                   3.975
# Lasso Regression                    3.281
# Ridge Regression                    3.884
# Support Vector Regression           9.118
# Decision Tree Regression            3.500
# Random Forest Regression            1.161

# %%
best_model
# Out:
# 'Random Forest Regression'

# %% [markdown]
# ### Exporting best model

# %%
metrics_performance, best_model = regression_train_test(x_train=X_train, y_train=Y_train, x_test=X_test, y_test=Y_test, export_best=True)

# %% [markdown]
# ### Loading and Predicting

# %%
from ubml.train_test import load_model

model = load_model("best_model.pkl")

# %%
dataset.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Seller_Type  Transmission  Owner
# 0            0             0      0
# 1            0             0      0
# 2            0             0      0
# 3            0             0      0
# 4            0             0      0

# %%
from ubml.train_test import predict

prediction = predict("best_model.pkl", input=[2013, 9.54, 43000, 1, 0, 0, 0])
prediction
# Out:
# 5.122599999999998

# %% [markdown]
# ## Testing model_train_test()

# %%
from ubml.train_test import model_train_test

metrics_performance, best_model = model_train_test(mode="regression", x_train=X_train, y_train=Y_train, x_test=X_test, y_test=Y_test)
print(best_model)
metrics_performance
# Out:
# Random Forest Regression
#                            r2 score train  r2 score test  \
# Linear Regression                   0.880          0.837
# Lasso Regression                    0.843          0.871
# Ridge Regression                    0.880          0.840
# Support Vector Regression          -0.078          0.109
# Decision Tree Regression            1.000          0.927
# Random Forest Regression            0.986          0.977
#
#                            mean squared error train  mean squared error test  \
# Linear Regression                             3.259                    2.150
# Lasso Regression                              4.268                    1.698
# Ridge Regression                              3.260                    2.104
# Support Vector Regression                    29.252                   11.729
# Decision Tree Regression                      0.000                    0.958
# Random Forest Regression                      0.370                    0.297
#
#                            root mean squared error train  \
# Linear Regression                                  1.805
# Lasso Regression                                   2.066
# Ridge Regression                                   1.806
# Support Vector Regression                          5.409
# Decision Tree Regression                           0.000
# Random Forest Regression                           0.609
#
#                            root mean squared error test  \
# Linear Regression                                 1.466
# Lasso Regression                                  1.303
# Ridge Regression                                  1.450
# Support Vector Regression                         3.425
# Decision Tree Regression                          0.979
# Random Forest Regression                          0.545
#
#                            mean absolute error train  \
# Linear Regression                              1.217
# Lasso Regression                               1.286
# Ridge Regression                               1.213
# Support Vector Regression                      3.236
# Decision Tree Regression                       0.000
# Random Forest Regression                       0.241
#
#                            mean absolute error test  \
# Linear Regression                             1.152
# Lasso Regression                              1.051
# Ridge Regression                              1.143
# Support Vector Regression                     2.679
# Decision Tree Regression                      0.524
# Random Forest Regression                      0.351
#
#                            explained variance score train  \
# Linear Regression                                   0.880
# Lasso Regression                                    0.843
# Ridge Regression                                    0.880
# Support Vector Regression                          -0.003
# Decision Tree Regression                            1.000
# Random Forest Regression                            0.986
#
#                            explained variance score test  max error train  \
# Linear Regression                                  0.846           11.078
# Lasso Regression                                   0.871           12.380
# Ridge Regression                                   0.849           11.113
# Support Vector Regression                          0.161           31.218
# Decision Tree Regression                           0.928            0.000
# Random Forest Regression                           0.979            6.704
#
#                            max error test
# Linear Regression                   3.975
# Lasso Regression                    3.281
# Ridge Regression                    3.884
# Support Vector Regression           9.118
# Decision Tree Regression            4.250
# Random Forest Regression            1.931

# %% [markdown]
# ### Testing Classification

# %%
dataset = pd.read_csv('data/classification/heart.csv')
X = dataset.drop(columns='target', axis=1)
Y = dataset['target']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
from ubml.train_test import classification_train_test

metrics_performance, best_model = classification_train_test(x_train=X_train, y_train=Y_train, x_test=X_test, y_test=Y_test)
print(best_model)
metrics_performance
# Out:
# Logistic Regression
#                           accuracy score train  accuracy score test  \
# Logistic Regression                      0.852                0.805
# KNN Classifier                           0.906                0.722
# SVM Classifier                           0.721                0.707
# Naive Bayes Classifier                   0.839                0.780
# Decision Tree Classifier                 1.000                1.000
# Random Forest Classifier                 1.000                1.000
#
#                           f1 score train  f1 score test  recall score train  \
# Logistic Regression                0.863          0.823               0.903
# KNN Classifier                     0.907          0.722               0.893
# SVM Classifier                     0.741          0.732               0.777
# Naive Bayes Classifier             0.848          0.791               0.874
# Decision Tree Classifier           1.000          1.000               1.000
# Random Forest Classifier           1.000          1.000               1.000
#
#                           recall score test  jaccard score train  \
# Logistic Regression                   0.886                0.758
# KNN Classifier                        0.705                0.830
# SVM Classifier                        0.781                0.588
# Naive Bayes Classifier                0.810                0.736
# Decision Tree Classifier              1.000                1.000
# Random Forest Classifier              1.000                1.000
#
#                           jaccard score test  precision score train  \
# Logistic Regression                    0.699                  0.826
# KNN Classifier                         0.565                  0.922
# SVM Classifier                         0.577                  0.708
# Naive Bayes Classifier                 0.654                  0.823
# Decision Tree Classifier               1.000                  1.000
# Random Forest Classifier               1.000                  1.000
#
#                           precision score test
# Logistic Regression                      0.769
# KNN Classifier                           0.740
# SVM Classifier                           0.689
# Naive Bayes Classifier                   0.773
# Decision Tree Classifier                 1.000
# Random Forest Classifier                 1.000
